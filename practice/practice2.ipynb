# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.preprocessing import LabelEncoder,OneHotEncoder,StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

# %%
data_url="https://raw.githubusercontent.com/digipodium/Datasets/main/bank_data.csv"
df=pd.read_csv(data_url,index_col=0)
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# ...

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.isnull().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# ...

# %%
def val(geography):
    return isinstance(geography,str)

print(df['Geography'].apply(val))
# Out:
# RowNumber
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
#          ...
# 9996     True
# 9997     True
# 9998     True
# 9999     True
# 10000    True
# Name: Geography, Length: 10000, dtype: bool

# %%
df.drop(['CustomerId','Surname','Gender','NumOfProducts','HasCrCard','IsActiveMember','Exited'],axis=1,inplace=True)
df
# Out:
#            CreditScore Geography  Age  Tenure    Balance  EstimatedSalary
# RowNumber
# 1                  619    France   42       2       0.00        101348.88
# 2                  608     Spain   41       1   83807.86        112542.58
# 3                  502    France   42       8  159660.80        113931.57
# 4                  699    France   39       1       0.00         93826.63
# 5                  850     Spain   43       2  125510.82         79084.10
# ...                ...       ...  ...     ...        ...              ...
# 9996               771    France   39       5       0.00         96270.64
# 9997               516    France   35      10   57369.61        101699.77
# 9998               709    France   36       7       0.00         42085.58
# 9999               772   Germany   42       3   75075.31         92888.52
# 10000              792    France   28       4  130142.79         38190.78
#
# [10000 rows x 6 columns]

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
geo_enc=LabelEncoder()
geo_enc.fit(df['Geography'])
# Out:
# LabelEncoder()

# %%
df['Geography']=geo_enc.transform(df['Geography'])
df
# Out:
#            CreditScore  Geography  Age  Tenure    Balance  EstimatedSalary
# RowNumber
# 1                  619          0   42       2       0.00        101348.88
# 2                  608          2   41       1   83807.86        112542.58
# 3                  502          0   42       8  159660.80        113931.57
# 4                  699          0   39       1       0.00         93826.63
# 5                  850          2   43       2  125510.82         79084.10
# ...                ...        ...  ...     ...        ...              ...
# 9996               771          0   39       5       0.00         96270.64
# 9997               516          0   35      10   57369.61        101699.77
# 9998               709          0   36       7       0.00         42085.58
# 9999               772          1   42       3   75075.31         92888.52
# 10000              792          0   28       4  130142.79         38190.78
#
# [10000 rows x 6 columns]

# %%
geo_enc.classes_
# Out:
# array(['France', 'Germany', 'Spain'], dtype=object)

# %%
df.values
# Out:
# array([[6.1900000e+02, 0.0000000e+00, 4.2000000e+01, 2.0000000e+00,
#         0.0000000e+00, 1.0134888e+05],
#        [6.0800000e+02, 2.0000000e+00, 4.1000000e+01, 1.0000000e+00,
#         8.3807860e+04, 1.1254258e+05],
#        [5.0200000e+02, 0.0000000e+00, 4.2000000e+01, 8.0000000e+00,
#         1.5966080e+05, 1.1393157e+05],
#        ...,
#        [7.0900000e+02, 0.0000000e+00, 3.6000000e+01, 7.0000000e+00,
#         0.0000000e+00, 4.2085580e+04],
#        [7.7200000e+02, 1.0000000e+00, 4.2000000e+01, 3.0000000e+00,
#         7.5075310e+04, 9.2888520e+04],
#        [7.9200000e+02, 0.0000000e+00, 2.8000000e+01, 4.0000000e+00,
#         1.3014279e+05, 3.8190780e+04]])

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
estimated_sal=OneHotEncoder(drop='first')
estimated_sal.fit(df[['EstimatedSalary']])
# Out:
# OneHotEncoder(drop='first')

# %%
estimated_dummies=estimated_sal.transform(df[['EstimatedSalary']])

# %%
df.drop(columns=['EstimatedSalary','RowNumber'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [60], in <module>
# ----> 1 df.drop(columns=['EstimatedSalary','RowNumber'],axis=1,inplace=True)
#
# File ~\miniconda3\envs\digi1\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\miniconda3\envs\digi1\lib\site-packages\pandas\core\frame.py:4956, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4809 def drop(
#    4810     self,
#    (...)
# ...

# %%
df.values
# Out:
# array([[6.1900000e+02, 0.0000000e+00, 4.2000000e+01, 2.0000000e+00,
#         0.0000000e+00],
#        [6.0800000e+02, 2.0000000e+00, 4.1000000e+01, 1.0000000e+00,
#         8.3807860e+04],
#        [5.0200000e+02, 0.0000000e+00, 4.2000000e+01, 8.0000000e+00,
#         1.5966080e+05],
#        ...,
#        [7.0900000e+02, 0.0000000e+00, 3.6000000e+01, 7.0000000e+00,
#         0.0000000e+00],
#        [7.7200000e+02, 1.0000000e+00, 4.2000000e+01, 3.0000000e+00,
#         7.5075310e+04],
#        [7.9200000e+02, 0.0000000e+00, 2.8000000e+01, 4.0000000e+00,
#         1.3014279e+05]])

# %%
df
# Out:
#            CreditScore  Geography  Age  Tenure    Balance
# RowNumber
# 1                  619          0   42       2       0.00
# 2                  608          2   41       1   83807.86
# 3                  502          0   42       8  159660.80
# 4                  699          0   39       1       0.00
# 5                  850          2   43       2  125510.82
# ...                ...        ...  ...     ...        ...
# 9996               771          0   39       5       0.00
# 9997               516          0   35      10   57369.61
# 9998               709          0   36       7       0.00
# 9999               772          1   42       3   75075.31
# 10000              792          0   28       4  130142.79
#
# [10000 rows x 5 columns]

# %%
import numpy as np

# %%
data=np.hstack((estimated_dummies,df.values))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [59], in <module>
# ----> 1 data=np.hstack((estimated_dummies,df.values))
#
# File <__array_function__ internals>:180, in hstack(*args, **kwargs)
#
# File ~\miniconda3\envs\digi1\lib\site-packages\numpy\core\shape_base.py:343, in hstack(tup)
#     341 # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     342 if arrs and arrs[0].ndim == 1:
# --> 343     return _nx.concatenate(arrs, 0)
#     344 else:
#     345     return _nx.concatenate(arrs, 1)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
e
