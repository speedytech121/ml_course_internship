# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
df=pd.read_csv("https://gist.githubusercontent.com/jwalsh/ce1dc0436aba5b7a5c9666f47fa5a380/raw/5ce3854392b43ff97907112d344fc008229b0445/titanic.csv")
pd.set_option('display.max_columns',None)
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
df.notnull()
# Out:
#      PassengerId  Survived  Pclass  Lname  Name   Sex    Age  SibSp  Parch  \
# 0           True      True    True   True  True  True   True   True   True
# 1           True      True    True   True  True  True   True   True   True
# 2           True      True    True   True  True  True   True   True   True
# 3           True      True    True   True  True  True   True   True   True
# 4           True      True    True   True  True  True   True   True   True
# ..           ...       ...     ...    ...   ...   ...    ...    ...    ...
# 151         True      True    True   True  True  True   True   True   True
# 152         True      True    True   True  True  True   True   True   True
# 153         True      True    True   True  True  True   True   True   True
# 154         True      True    True   True  True  True  False   True   True
# 155         True      True    True   True  True  True   True   True   True
#
#      Ticket  Fare  Cabin  Embarked
# 0      True  True  False      True
# 1      True  True   True      True
# 2      True  True  False      True
# 3      True  True   True      True
# 4      True  True  False      True
# ..      ...   ...    ...       ...
# 151    True  True   True      True
# 152    True  True  False      True
# 153    True  True  False      True
# 154    True  True  False      True
# 155    True  True  False      True
#
# [156 rows x 13 columns]

# %%
imputer=SimpleImputer()
cols=['Age']
df[cols]=imputer.fit_transform(df[cols])
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name     Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    male  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                  Miss. Laina  female  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                            Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.isnull().sum().sum()
# Out:
# 126

# %%
df.drop(['Cabin'],axis=1)
print(df.isnull().sum())
df.drop(['Embarked',],axis=1)
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64
# PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
featSelector=SelectKBest(chi2,k=5)

# %%
numerical_cols=df.select_dtypes(include=['int','float']).columns.tolist()
categorical_cols=df.select_dtypes(include=['object']).columns.tolist()

# %%
df[categorical_cols].nunique()
# Out:
# Lname       141
# Name        152
# Sex           2
# Ticket      145
# Cabin        28
# Embarked      3
# dtype: int64

# %% [markdown]
# convert all the selected categorical columns to numerical using label encoder or onehot encoding

# %%
a=0
label_li=[]
onehot_li=[]
for i in range(len(categorical_cols)):
    a=len(df[categorical_cols[i]].value_counts().tolist())
    if(a<=2):
        label_li.append(categorical_cols[i])
    else:
        onehot_li.append(categorical_cols[i])
    a=0

print(label_li)
print(onehot_li)
# Out:
# ['Sex']
# ['Lname', 'Name', 'Ticket', 'Cabin', 'Embarked']

# %%
from sklearn.preprocessing import LabelEncoder
def labelencoding():
    label_variable=['Sex']
    for i in range(len(label_variable)):
        label_variable[i]=LabelEncoder()
        label_variable[i].fit(df[label_li[i]])
        df[label_li[i]]=label_variable[i].transform(df[label_li[i]])

    print(df.head())
labelencoding()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name  Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    1  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)    0  38.0      1      0
# 2                                  Miss. Laina    0  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                            Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
from sklearn.preprocessing import OneHotEncoder
onehot_enc=['Lname', 'Name', 'Ticket', 'Cabin', 'Embarked']
for i in range(len(onehot_enc)):
    onehot_enc[i]=OneHotEncoder(drop='first')
    onehot_enc[i].fit(df[[onehot_li[i]]])

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name  Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    1  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)    0  38.0      1      0
# 2                                  Miss. Laina    0  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                            Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
imputer=SimpleImputer()
cols=['Age']
df[cols]=imputer.fit_transform(df[cols])
df.head()
# Out:
#    PassengerId  Survived  Pclass      Lname  \
# 0            1         0       3     Braund
# 1            2         1       1    Cumings
# 2            3         1       3  Heikkinen
# 3            4         1       1   Futrelle
# 4            5         0       3      Allen
#
#                                           Name  Sex   Age  SibSp  Parch  \
# 0                              Mr. Owen Harris    1  22.0      1      0
# 1   Mrs. John Bradley (Florence Briggs Thayer)    0  38.0      1      0
# 2                                  Miss. Laina    0  26.0      0      0
# 3           Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                            Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
featSelector=SelectKBest(chi2,k=all)

# %%
X=df[['Pclass','Sex','Age','Parch']] 
y=df['Survived']
print(X.shape,y.shape)
# Out:
# (30, 4) (30,)

# %%
featSelector.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\ml_course\supervised\classification\titanic_feature_selection.ipynb Cell 19' in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/ml_course/supervised/classification/titanic_feature_selection.ipynb#ch0000005?line=0'>1</a> featSelector.fit(X,y)
#
# File ~\miniconda3\envs\digi1\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:407, in _BaseFilter.fit(self, X, y)
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=400'>401</a> if not callable(self.score_func):
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=401'>402</a>     raise TypeError(
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=402'>403</a>         "The score function should be a callable, %s (%s) was passed."
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=403'>404</a>         % (self.score_func, type(self.score_func))
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=404'>405</a>     )
# --> <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=406'>407</a> self._check_params(X, y)
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=407'>408</a> score_func_ret = self.score_func(X, y)
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=408'>409</a> if isinstance(score_func_ret, (list, tuple)):
#
# File ~\miniconda3\envs\digi1\lib\site-packages\sklearn\feature_selection\_univariate_selection.py:603, in SelectKBest._check_params(self, X, y)
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=601'>602</a> def _check_params(self, X, y):
# --> <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=602'>603</a>     if not (self.k == "all" or 0 <= self.k <= X.shape[1]):
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=603'>604</a>         raise ValueError(
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=604'>605</a>             "k should be >=0, <= n_features = %d; got %r. "
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=605'>606</a>             "Use k='all' to return all features." % (X.shape[1], self.k)
#     <a href='file:///~/miniconda3/envs/digi1/lib/site-packages/sklearn/feature_selection/_univariate_selection.py?line=606'>607</a>         )
#
# TypeError: '<=' not supported between instances of 'int' and 'builtin_function_or_method'
