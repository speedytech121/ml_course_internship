# %% [markdown]
# - to find accuracy
#
# - find grid and do hypertuning
# - for gridding we use GRID SEARCH
# - AND GET TABLE OF EVALUATION OF BEST SETTINGS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px #for three dimension graphs
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import plot_tree

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error

from joblib import dump, load

# %%
df=pd.read_csv("https://raw.githubusercontent.com/digipodium/Datasets/main/house_pricing.csv")

# %%
X=df[['Beds','Baths','SquareFeet']]
y=df['Price']
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=.2,random_state=True)

# %%
print("RANDOM FOREST REGRESSOR")
model2=RandomForestRegressor()
model2.fit(xtrain,ytrain)
print("score:",model2.score(xtest,ytest)*100)
pred=model2.predict(X)
print("mae:",mean_absolute_error(y,pred))
print("mse:",mean_squared_error(y,pred))
# Out:
# RANDOM FOREST REGRESSOR
# score: 72.0208469421146
# mae: 15197.781272064662
# mse: 873918714.2003858

# %%
forest_score=cross_val_score(model2,X,y,cv=10)
print(forest_score,f"average:{forest_score.mean():.2f}",f"std:{forest_score.std():.2f}")
# Out:
# [ 0.54972733  0.77818407  0.49120181  0.719304    0.08476315  0.57160038
#  -0.03937138  0.24501854  0.56142076  0.5083297 ] average:0.45 std:0.25

# %% [markdown]
# grid search

# %%
#we are going to create a dictionary with all the parameter and their value options

# %%
params={
    'n_estimators': list(range(100,501,100)),
    'criterion':["squared_error","absolute_error","poisson"],
    'max_depth': list(range(5,50,20))
}
params
# Out:
# {'n_estimators': [100, 200, 300, 400, 500],
#  'criterion': ['squared_error', 'absolute_error', 'poisson'],
#  'max_depth': [5, 25, 45]}

# %%
grid=GridSearchCV(estimator=RandomForestRegressor(),param_grid=params,cv=3,n_jobs=-1,verbose=2)

# %%
grid.fit(X,y)
# Out:
# Fitting 3 folds for each of 45 candidates, totalling 135 fits
# GridSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'poisson'],
#                          'max_depth': [5, 25, 45],
#                          'n_estimators': [100, 200, 300, 400, 500]},
#              verbose=2)

# %%
gf=pd.DataFrame(grid.cv_results_)

# %%
gf
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.419429      0.166459         0.015337        0.000945
# 1        0.554459      0.222566         0.027005        0.001633
# 2        0.553458      0.008995         0.038342        0.002626
# 3        0.876195      0.106798         0.052012        0.002829
# 4        0.984221      0.061175         0.062014        0.002161
# 5        0.251721      0.011559         0.018337        0.000472
# 6        0.477108      0.011779         0.034673        0.002867
# 7        0.714492      0.007717         0.048345        0.000945
# 8        0.955213      0.020071         0.066682        0.001887
# 9        1.193602      0.030951         0.083352        0.003400
# 10       0.240384      0.001699         0.019005        0.000816
# 11       0.492443      0.011900         0.034008        0.001413
# 12       0.680152      0.012086         0.040342        0.000944
# 13       0.866363      0.009636         0.048848        0.000849
# 14       0.846364      0.019674         0.051679        0.001247
# 15       0.353247      0.008878         0.012338        0.004028
# 16       0.653811      0.002055         0.020672        0.003859
# 17       0.968216      0.026324         0.027008        0.001415
# 18       1.304625      0.018665         0.033676        0.000472
# 19       1.597021      0.015844         0.043343        0.001247
# 20       0.456435      0.010341         0.011336        0.000471
# 21       0.924873      0.003860         0.023339        0.001248
# 22       1.375310      0.019135         0.033007        0.002452
# 23       1.835581      0.012257         0.044344        0.001248
# 24       2.303353      0.040087         0.054679        0.001886
# 25       0.463103      0.000816         0.013337        0.001248
# 26       0.936209      0.017286         0.024674        0.002358
# 27       1.473997      0.032568         0.034340        0.001698
# 28       1.978108      0.003300         0.046344        0.001248
# 29       2.511232      0.017560         0.056012        0.000816
# 30       0.137696      0.002494         0.010003        0.001414
# 31       0.270393      0.001700         0.018337        0.000471
# 32       0.414760      0.004786         0.024673        0.000471
# 33       0.546455      0.004498         0.034676        0.001248
# 34       0.702492      0.005250         0.042676        0.001247
# 35       0.232719      0.006550         0.011671        0.000943
# 36       0.454768      0.003300         0.024005        0.001633
# 37       0.680152      0.002162         0.033341        0.001248
# 38       0.914536      0.009845         0.043678        0.001701
# 39       1.133253      0.011577         0.052680        0.001247
# 40       0.280061      0.002449         0.014672        0.000472
# 41       0.553790      0.010628         0.026673        0.000943
# 42       0.818517      0.008808         0.038342        0.000472
# 43       1.100912      0.006343         0.047010        0.000817
# 44       1.256948      0.027652         0.052349        0.001700
#
#    param_criterion param_max_depth param_n_estimators  \
# 0    squared_error               5                100
# 1    squared_error               5                200
# 2    squared_error               5                300
# 3    squared_error               5                400
# 4    squared_error               5                500
# 5    squared_error              25                100
# 6    squared_error              25                200
# 7    squared_error              25                300
# 8    squared_error              25                400
# 9    squared_error              25                500
# 10   squared_error              45                100
# 11   squared_error              45                200
# 12   squared_error              45                300
# 13   squared_error              45                400
# 14   squared_error              45                500
# 15  absolute_error               5                100
# 16  absolute_error               5                200
# 17  absolute_error               5                300
# 18  absolute_error               5                400
# 19  absolute_error               5                500
# 20  absolute_error              25                100
# 21  absolute_error              25                200
# 22  absolute_error              25                300
# 23  absolute_error              25                400
# 24  absolute_error              25                500
# 25  absolute_error              45                100
# 26  absolute_error              45                200
# 27  absolute_error              45                300
# 28  absolute_error              45                400
# 29  absolute_error              45                500
# 30         poisson               5                100
# 31         poisson               5                200
# 32         poisson               5                300
# 33         poisson               5                400
# 34         poisson               5                500
# 35         poisson              25                100
# 36         poisson              25                200
# 37         poisson              25                300
# 38         poisson              25                400
# 39         poisson              25                500
# 40         poisson              45                100
# 41         poisson              45                200
# 42         poisson              45                300
# 43         poisson              45                400
# 44         poisson              45                500
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_depth': 5,...           0.799223
# 1   {'criterion': 'squared_error', 'max_depth': 5,...           0.800358
# 2   {'criterion': 'squared_error', 'max_depth': 5,...           0.803909
# 3   {'criterion': 'squared_error', 'max_depth': 5,...           0.802221
# 4   {'criterion': 'squared_error', 'max_depth': 5,...           0.801588
# 5   {'criterion': 'squared_error', 'max_depth': 25...           0.748251
# 6   {'criterion': 'squared_error', 'max_depth': 25...           0.749385
# 7   {'criterion': 'squared_error', 'max_depth': 25...           0.757123
# 8   {'criterion': 'squared_error', 'max_depth': 25...           0.754182
# 9   {'criterion': 'squared_error', 'max_depth': 25...           0.756439
# 10  {'criterion': 'squared_error', 'max_depth': 45...           0.752037
# 11  {'criterion': 'squared_error', 'max_depth': 45...           0.762244
# 12  {'criterion': 'squared_error', 'max_depth': 45...           0.753658
# 13  {'criterion': 'squared_error', 'max_depth': 45...           0.750380
# 14  {'criterion': 'squared_error', 'max_depth': 45...           0.751960
# 15  {'criterion': 'absolute_error', 'max_depth': 5...           0.823549
# 16  {'criterion': 'absolute_error', 'max_depth': 5...           0.824175
# 17  {'criterion': 'absolute_error', 'max_depth': 5...           0.824155
# 18  {'criterion': 'absolute_error', 'max_depth': 5...           0.827372
# 19  {'criterion': 'absolute_error', 'max_depth': 5...           0.821918
# 20  {'criterion': 'absolute_error', 'max_depth': 2...           0.772375
# 21  {'criterion': 'absolute_error', 'max_depth': 2...           0.770736
# 22  {'criterion': 'absolute_error', 'max_depth': 2...           0.765704
# 23  {'criterion': 'absolute_error', 'max_depth': 2...           0.763573
# 24  {'criterion': 'absolute_error', 'max_depth': 2...           0.769381
# 25  {'criterion': 'absolute_error', 'max_depth': 4...           0.763196
# 26  {'criterion': 'absolute_error', 'max_depth': 4...           0.765154
# 27  {'criterion': 'absolute_error', 'max_depth': 4...           0.767933
# 28  {'criterion': 'absolute_error', 'max_depth': 4...           0.772752
# 29  {'criterion': 'absolute_error', 'max_depth': 4...           0.762601
# 30  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.343221
# 31  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.350716
# 32  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.347679
# 33  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.348232
# 34  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.341192
# 35  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.724008
# 36  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.731034
# 37  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.722897
# 38  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.719215
# 39  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.720330
# 40  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.736651
# 41  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.744949
# 42  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.751188
# 43  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.744069
# 44  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.743191
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0            0.764633           0.622912         0.728923        0.076280
# 1            0.765569           0.617037         0.727654        0.079497
# 2            0.766771           0.615808         0.728829        0.081344
# 3            0.766741           0.617885         0.728949        0.079859
# 4            0.766935           0.619804         0.729442        0.078806
# 5            0.754860           0.589751         0.697621        0.076323
# 6            0.751083           0.578707         0.693058        0.080861
# 7            0.753512           0.580642         0.697092        0.082356
# 8            0.753019           0.584872         0.697358        0.079541
# 9            0.754078           0.580786         0.697101        0.082253
# 10           0.750303           0.574062         0.692134        0.083492
# 11           0.753620           0.576438         0.697434        0.085629
# 12           0.755813           0.578337         0.695936        0.083159
# 13           0.754075           0.583228         0.695894        0.079682
# 14           0.752685           0.579820         0.694822        0.081319
# 15           0.767462           0.612123         0.734378        0.089429
# 16           0.765208           0.610647         0.733344        0.090037
# 17           0.768864           0.614879         0.735966        0.088547
# 18           0.768407           0.613842         0.736540        0.090039
# 19           0.766653           0.614063         0.734211        0.087902
# 20           0.759167           0.575531         0.702358        0.089842
# 21           0.758899           0.587336         0.705657        0.083805
# 22           0.760743           0.572704         0.699717        0.089835
# 23           0.760025           0.574067         0.699222        0.088509
# 24           0.759068           0.576493         0.701647        0.088598
# 25           0.757504           0.570563         0.697088        0.089497
# 26           0.757925           0.575912         0.699663        0.087555
# 27           0.759801           0.580244         0.702659        0.086625
# 28           0.758872           0.578126         0.703250        0.088657
# 29           0.759106           0.578668         0.700125        0.085895
# 30           0.498178           0.160431         0.333944        0.138041
# 31           0.507579           0.162245         0.340180        0.141179
# 32           0.505939           0.155904         0.336508        0.143119
# 33           0.492590           0.156634         0.332486        0.137605
# 34           0.502180           0.158238         0.333870        0.140509
# 35           0.746139           0.539384         0.669844        0.092690
# 36           0.743359           0.544769         0.673054        0.090851
# 37           0.744185           0.539965         0.669016        0.091666
# 38           0.744649           0.537078         0.666981        0.092440
# 39           0.746893           0.539896         0.669040        0.091960
# 40           0.755056           0.569005         0.686904        0.083705
# 41           0.755818           0.570152         0.690306        0.085078
# 42           0.757304           0.575434         0.694642        0.084330
# 43           0.756199           0.575651         0.691973        0.082401
# 44           0.754702           0.577113         0.691669        0.081139
#
#     rank_test_score
# 0                 8
# 1                10
# 2                 9
# 3                 7
# 4                 6
# 5                20
# 6                30
# 7                24
# 8                22
# 9                23
# 10               31
# 11               21
# 12               26
# 13               27
# 14               28
# 15                3
# 16                5
# 17                2
# 18                1
# 19                4
# 20               14
# 21               11
# 22               17
# 23               19
# 24               15
# 25               25
# 26               18
# 27               13
# 28               12
# 29               16
# 30               43
# 31               41
# 32               42
# 33               45
# 34               44
# 35               37
# 36               36
# 37               39
# 38               40
# 39               38
# 40               35
# 41               34
# 42               29
# 43               32
# 44               33

# %%
gf.sort_values(by='rank_test_score',inplace=True)

# %%
gf
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 18       1.304625      0.018665         0.033676        0.000472
# 17       0.968216      0.026324         0.027008        0.001415
# 15       0.353247      0.008878         0.012338        0.004028
# 19       1.597021      0.015844         0.043343        0.001247
# 16       0.653811      0.002055         0.020672        0.003859
# 4        0.984221      0.061175         0.062014        0.002161
# 3        0.876195      0.106798         0.052012        0.002829
# 0        0.419429      0.166459         0.015337        0.000945
# 2        0.553458      0.008995         0.038342        0.002626
# 1        0.554459      0.222566         0.027005        0.001633
# 21       0.924873      0.003860         0.023339        0.001248
# 28       1.978108      0.003300         0.046344        0.001248
# 27       1.473997      0.032568         0.034340        0.001698
# 20       0.456435      0.010341         0.011336        0.000471
# 24       2.303353      0.040087         0.054679        0.001886
# 29       2.511232      0.017560         0.056012        0.000816
# 22       1.375310      0.019135         0.033007        0.002452
# 26       0.936209      0.017286         0.024674        0.002358
# 23       1.835581      0.012257         0.044344        0.001248
# 5        0.251721      0.011559         0.018337        0.000472
# 11       0.492443      0.011900         0.034008        0.001413
# 8        0.955213      0.020071         0.066682        0.001887
# 9        1.193602      0.030951         0.083352        0.003400
# 7        0.714492      0.007717         0.048345        0.000945
# 25       0.463103      0.000816         0.013337        0.001248
# 12       0.680152      0.012086         0.040342        0.000944
# 13       0.866363      0.009636         0.048848        0.000849
# 14       0.846364      0.019674         0.051679        0.001247
# 42       0.818517      0.008808         0.038342        0.000472
# 6        0.477108      0.011779         0.034673        0.002867
# 10       0.240384      0.001699         0.019005        0.000816
# 43       1.100912      0.006343         0.047010        0.000817
# 44       1.256948      0.027652         0.052349        0.001700
# 41       0.553790      0.010628         0.026673        0.000943
# 40       0.280061      0.002449         0.014672        0.000472
# 36       0.454768      0.003300         0.024005        0.001633
# 35       0.232719      0.006550         0.011671        0.000943
# 39       1.133253      0.011577         0.052680        0.001247
# 37       0.680152      0.002162         0.033341        0.001248
# 38       0.914536      0.009845         0.043678        0.001701
# 31       0.270393      0.001700         0.018337        0.000471
# 32       0.414760      0.004786         0.024673        0.000471
# 30       0.137696      0.002494         0.010003        0.001414
# 34       0.702492      0.005250         0.042676        0.001247
# 33       0.546455      0.004498         0.034676        0.001248
#
#    param_criterion param_max_depth param_n_estimators  \
# 18  absolute_error               5                400
# 17  absolute_error               5                300
# 15  absolute_error               5                100
# 19  absolute_error               5                500
# 16  absolute_error               5                200
# 4    squared_error               5                500
# 3    squared_error               5                400
# 0    squared_error               5                100
# 2    squared_error               5                300
# 1    squared_error               5                200
# 21  absolute_error              25                200
# 28  absolute_error              45                400
# 27  absolute_error              45                300
# 20  absolute_error              25                100
# 24  absolute_error              25                500
# 29  absolute_error              45                500
# 22  absolute_error              25                300
# 26  absolute_error              45                200
# 23  absolute_error              25                400
# 5    squared_error              25                100
# 11   squared_error              45                200
# 8    squared_error              25                400
# 9    squared_error              25                500
# 7    squared_error              25                300
# 25  absolute_error              45                100
# 12   squared_error              45                300
# 13   squared_error              45                400
# 14   squared_error              45                500
# 42         poisson              45                300
# 6    squared_error              25                200
# 10   squared_error              45                100
# 43         poisson              45                400
# 44         poisson              45                500
# 41         poisson              45                200
# 40         poisson              45                100
# 36         poisson              25                200
# 35         poisson              25                100
# 39         poisson              25                500
# 37         poisson              25                300
# 38         poisson              25                400
# 31         poisson               5                200
# 32         poisson               5                300
# 30         poisson               5                100
# 34         poisson               5                500
# 33         poisson               5                400
#
#                                                params  split0_test_score  \
# 18  {'criterion': 'absolute_error', 'max_depth': 5...           0.827372
# 17  {'criterion': 'absolute_error', 'max_depth': 5...           0.824155
# 15  {'criterion': 'absolute_error', 'max_depth': 5...           0.823549
# 19  {'criterion': 'absolute_error', 'max_depth': 5...           0.821918
# 16  {'criterion': 'absolute_error', 'max_depth': 5...           0.824175
# 4   {'criterion': 'squared_error', 'max_depth': 5,...           0.801588
# 3   {'criterion': 'squared_error', 'max_depth': 5,...           0.802221
# 0   {'criterion': 'squared_error', 'max_depth': 5,...           0.799223
# 2   {'criterion': 'squared_error', 'max_depth': 5,...           0.803909
# 1   {'criterion': 'squared_error', 'max_depth': 5,...           0.800358
# 21  {'criterion': 'absolute_error', 'max_depth': 2...           0.770736
# 28  {'criterion': 'absolute_error', 'max_depth': 4...           0.772752
# 27  {'criterion': 'absolute_error', 'max_depth': 4...           0.767933
# 20  {'criterion': 'absolute_error', 'max_depth': 2...           0.772375
# 24  {'criterion': 'absolute_error', 'max_depth': 2...           0.769381
# 29  {'criterion': 'absolute_error', 'max_depth': 4...           0.762601
# 22  {'criterion': 'absolute_error', 'max_depth': 2...           0.765704
# 26  {'criterion': 'absolute_error', 'max_depth': 4...           0.765154
# 23  {'criterion': 'absolute_error', 'max_depth': 2...           0.763573
# 5   {'criterion': 'squared_error', 'max_depth': 25...           0.748251
# 11  {'criterion': 'squared_error', 'max_depth': 45...           0.762244
# 8   {'criterion': 'squared_error', 'max_depth': 25...           0.754182
# 9   {'criterion': 'squared_error', 'max_depth': 25...           0.756439
# 7   {'criterion': 'squared_error', 'max_depth': 25...           0.757123
# 25  {'criterion': 'absolute_error', 'max_depth': 4...           0.763196
# 12  {'criterion': 'squared_error', 'max_depth': 45...           0.753658
# 13  {'criterion': 'squared_error', 'max_depth': 45...           0.750380
# 14  {'criterion': 'squared_error', 'max_depth': 45...           0.751960
# 42  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.751188
# 6   {'criterion': 'squared_error', 'max_depth': 25...           0.749385
# 10  {'criterion': 'squared_error', 'max_depth': 45...           0.752037
# 43  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.744069
# 44  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.743191
# 41  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.744949
# 40  {'criterion': 'poisson', 'max_depth': 45, 'n_e...           0.736651
# 36  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.731034
# 35  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.724008
# 39  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.720330
# 37  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.722897
# 38  {'criterion': 'poisson', 'max_depth': 25, 'n_e...           0.719215
# 31  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.350716
# 32  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.347679
# 30  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.343221
# 34  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.341192
# 33  {'criterion': 'poisson', 'max_depth': 5, 'n_es...           0.348232
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 18           0.768407           0.613842         0.736540        0.090039
# 17           0.768864           0.614879         0.735966        0.088547
# 15           0.767462           0.612123         0.734378        0.089429
# 19           0.766653           0.614063         0.734211        0.087902
# 16           0.765208           0.610647         0.733344        0.090037
# 4            0.766935           0.619804         0.729442        0.078806
# 3            0.766741           0.617885         0.728949        0.079859
# 0            0.764633           0.622912         0.728923        0.076280
# 2            0.766771           0.615808         0.728829        0.081344
# 1            0.765569           0.617037         0.727654        0.079497
# 21           0.758899           0.587336         0.705657        0.083805
# 28           0.758872           0.578126         0.703250        0.088657
# 27           0.759801           0.580244         0.702659        0.086625
# 20           0.759167           0.575531         0.702358        0.089842
# 24           0.759068           0.576493         0.701647        0.088598
# 29           0.759106           0.578668         0.700125        0.085895
# 22           0.760743           0.572704         0.699717        0.089835
# 26           0.757925           0.575912         0.699663        0.087555
# 23           0.760025           0.574067         0.699222        0.088509
# 5            0.754860           0.589751         0.697621        0.076323
# 11           0.753620           0.576438         0.697434        0.085629
# 8            0.753019           0.584872         0.697358        0.079541
# 9            0.754078           0.580786         0.697101        0.082253
# 7            0.753512           0.580642         0.697092        0.082356
# 25           0.757504           0.570563         0.697088        0.089497
# 12           0.755813           0.578337         0.695936        0.083159
# 13           0.754075           0.583228         0.695894        0.079682
# 14           0.752685           0.579820         0.694822        0.081319
# 42           0.757304           0.575434         0.694642        0.084330
# 6            0.751083           0.578707         0.693058        0.080861
# 10           0.750303           0.574062         0.692134        0.083492
# 43           0.756199           0.575651         0.691973        0.082401
# 44           0.754702           0.577113         0.691669        0.081139
# 41           0.755818           0.570152         0.690306        0.085078
# 40           0.755056           0.569005         0.686904        0.083705
# 36           0.743359           0.544769         0.673054        0.090851
# 35           0.746139           0.539384         0.669844        0.092690
# 39           0.746893           0.539896         0.669040        0.091960
# 37           0.744185           0.539965         0.669016        0.091666
# 38           0.744649           0.537078         0.666981        0.092440
# 31           0.507579           0.162245         0.340180        0.141179
# 32           0.505939           0.155904         0.336508        0.143119
# 30           0.498178           0.160431         0.333944        0.138041
# 34           0.502180           0.158238         0.333870        0.140509
# 33           0.492590           0.156634         0.332486        0.137605
#
#     rank_test_score
# 18                1
# 17                2
# 15                3
# 19                4
# 16                5
# 4                 6
# 3                 7
# 0                 8
# 2                 9
# 1                10
# 21               11
# 28               12
# 27               13
# 20               14
# 24               15
# 29               16
# 22               17
# 26               18
# 23               19
# 5                20
# 11               21
# 8                22
# 9                23
# 7                24
# 25               25
# 12               26
# 13               27
# 14               28
# 42               29
# 6                30
# 10               31
# 43               32
# 44               33
# 41               34
# 40               35
# 36               36
# 35               37
# 39               38
# 37               39
# 38               40
# 31               41
# 32               42
# 30               43
# 34               44
# 33               45
